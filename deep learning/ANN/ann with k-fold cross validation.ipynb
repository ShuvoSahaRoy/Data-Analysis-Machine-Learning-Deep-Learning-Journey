# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### Encoding categorical data

# %% [markdown]
# Label Encoding the "Gender" column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])

# %%
print(len(X))
X
# Out:
# 10000
# array([[619, 'France', 0, ..., 1, 1, 101348.88],
#        [608, 'Spain', 0, ..., 0, 1, 112542.58],
#        [502, 'France', 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 0, ..., 0, 1, 42085.58],
#        [772, 'Germany', 1, ..., 1, 0, 92888.52],
#        [792, 'France', 0, ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# One Hot Encoding the "Geography" column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 8000
# 2000

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Initializing the ANN with k-cross validation

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units=6, activation='relu'))
    classifier.add(Dense(units=6, activation='relu'))
    classifier.add(Dense(units=1, activation='sigmoid'))
    classifier.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy', metrics= ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, batch_size = 25, epochs = 20)
# Out:
# C:\Users\sshuv\AppData\Local\Temp\ipykernel_9416\3125785094.py:8: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = build_classifier, batch_size = 25, epochs = 20)

# %%
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10, n_jobs=1)
mean = accuracies.mean()
variance = accuracies.std()
# Out:
# Epoch 1/20
# 288/288 [==============================] - 2s 2ms/step - loss: 0.6080 - accuracy: 0.6982
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4703 - accuracy: 0.7986
# Epoch 3/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.8024
# Epoch 4/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.8051
# Epoch 5/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4225 - accuracy: 0.8057
# Epoch 6/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4161 - accuracy: 0.8072
# Epoch 7/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8100
# Epoch 8/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8100
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8101
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.8136
# Epoch 11/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3774 - accuracy: 0.8244
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8476
# Epoch 13/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8512
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3594 - accuracy: 0.8551
# Epoch 15/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8551
# Epoch 16/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3542 - accuracy: 0.8572
# Epoch 17/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3529 - accuracy: 0.8581
# Epoch 18/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8601
# Epoch 19/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.8585
# Epoch 20/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3491 - accuracy: 0.8608
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8600
# Epoch 1/20
# 288/288 [==============================] - 2s 2ms/step - loss: 0.6235 - accuracy: 0.6832
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4798 - accuracy: 0.7967
# Epoch 3/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4513 - accuracy: 0.7967
# Epoch 4/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4386 - accuracy: 0.7967
# Epoch 5/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4325 - accuracy: 0.7967
# Epoch 6/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4288 - accuracy: 0.7975
# Epoch 7/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4256 - accuracy: 0.8018
# Epoch 8/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8101
# Epoch 9/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4170 - accuracy: 0.8160
# Epoch 10/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4120 - accuracy: 0.8217
# Epoch 11/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4063 - accuracy: 0.8225
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8236
# Epoch 13/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8233
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8253
# Epoch 15/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8258
# Epoch 16/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8275
# Epoch 17/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8275
# Epoch 18/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8376
# Epoch 19/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8468
# Epoch 20/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8504
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3775 - accuracy: 0.8450
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.5175 - accuracy: 0.7956
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4628 - accuracy: 0.7956
# Epoch 3/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7974
# Epoch 4/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4385 - accuracy: 0.8008
# Epoch 5/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4338 - accuracy: 0.8101
# Epoch 6/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4304 - accuracy: 0.8144
# Epoch 7/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.8161
# Epoch 8/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4247 - accuracy: 0.8194
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8214
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.8225
# Epoch 11/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8254
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8256
# Epoch 13/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.8269
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.8265
# Epoch 15/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4121 - accuracy: 0.8278
# Epoch 16/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4107 - accuracy: 0.8294
# Epoch 17/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8311
# Epoch 18/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.8317
# Epoch 19/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4063 - accuracy: 0.8329
# Epoch 20/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4051 - accuracy: 0.8333
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8363
# Epoch 1/20
# 288/288 [==============================] - 2s 2ms/step - loss: 0.4922 - accuracy: 0.7975
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4502 - accuracy: 0.7975
# Epoch 3/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4349 - accuracy: 0.7975
# Epoch 4/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.7975
# Epoch 5/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.8071
# Epoch 6/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8200
# Epoch 7/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4171 - accuracy: 0.8225
# Epoch 8/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4151 - accuracy: 0.8253
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4131 - accuracy: 0.8264
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4109 - accuracy: 0.8278
# Epoch 11/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8283
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8300
# Epoch 13/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8278
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8301
# Epoch 15/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.8321
# Epoch 16/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8342
# Epoch 17/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8378
# Epoch 18/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8426
# Epoch 19/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8410
# Epoch 20/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8446
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8363
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.5777 - accuracy: 0.7408
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4791 - accuracy: 0.7958
# Epoch 3/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.7954
# Epoch 4/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4460 - accuracy: 0.8024
# Epoch 5/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4392 - accuracy: 0.8062
# Epoch 6/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4343 - accuracy: 0.8082
# Epoch 7/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4305 - accuracy: 0.8086
# Epoch 8/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4272 - accuracy: 0.8081
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4245 - accuracy: 0.8117
# Epoch 10/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4217 - accuracy: 0.8151
# Epoch 11/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4191 - accuracy: 0.8190
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4170 - accuracy: 0.8213
# Epoch 13/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8239
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.8249
# Epoch 15/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4114 - accuracy: 0.8274
# Epoch 16/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8274
# Epoch 17/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4074 - accuracy: 0.8276
# Epoch 18/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4055 - accuracy: 0.8314
# Epoch 19/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4030 - accuracy: 0.8297
# Epoch 20/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8322
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3786 - accuracy: 0.8475
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.5664 - accuracy: 0.7825
# Epoch 2/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.7944
# Epoch 3/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4642 - accuracy: 0.7956
# Epoch 4/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.8053
# Epoch 5/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4311 - accuracy: 0.8110
# Epoch 6/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4258 - accuracy: 0.8143
# Epoch 7/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.8174
# Epoch 8/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4198 - accuracy: 0.8199
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.8229
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4156 - accuracy: 0.8261
# Epoch 11/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.8301
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8292
# Epoch 13/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4098 - accuracy: 0.8313
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8315
# Epoch 15/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4068 - accuracy: 0.8343
# Epoch 16/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8343
# Epoch 17/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8336
# Epoch 18/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4034 - accuracy: 0.8349
# Epoch 19/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4028 - accuracy: 0.8336
# Epoch 20/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8335
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8313
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.5707 - accuracy: 0.7785
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.5066 - accuracy: 0.7969
# Epoch 3/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4723 - accuracy: 0.7979
# Epoch 4/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4507 - accuracy: 0.8056
# Epoch 5/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.8097
# Epoch 6/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4330 - accuracy: 0.8090
# Epoch 7/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8110
# Epoch 8/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8097
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8121
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.8110
# Epoch 11/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4201 - accuracy: 0.8147
# Epoch 12/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4172 - accuracy: 0.8160
# Epoch 13/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.8199
# Epoch 14/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4111 - accuracy: 0.8224
# Epoch 15/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4082 - accuracy: 0.8228
# Epoch 16/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.8254
# Epoch 17/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8268
# Epoch 18/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8269
# Epoch 19/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8319
# Epoch 20/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8349
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.8413
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.5493 - accuracy: 0.7835
# Epoch 2/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4649 - accuracy: 0.7962
# Epoch 3/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4386 - accuracy: 0.7964
# Epoch 4/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4225 - accuracy: 0.8089
# Epoch 5/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.4128 - accuracy: 0.8194
# Epoch 6/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4056 - accuracy: 0.8207
# Epoch 7/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8222
# Epoch 8/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8246
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8285
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8339
# Epoch 11/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8385
# Epoch 12/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3743 - accuracy: 0.8400
# Epoch 13/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.8418
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8447
# Epoch 15/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3608 - accuracy: 0.8490
# Epoch 16/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3574 - accuracy: 0.8486
# Epoch 17/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3547 - accuracy: 0.8524
# Epoch 18/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8550
# Epoch 19/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3484 - accuracy: 0.8579
# Epoch 20/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3455 - accuracy: 0.8572
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8512
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.6013 - accuracy: 0.7097
# Epoch 2/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4817 - accuracy: 0.7958
# Epoch 3/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.8017
# Epoch 4/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.8179
# Epoch 5/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4150 - accuracy: 0.8214
# Epoch 6/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8211
# Epoch 7/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8242
# Epoch 8/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8242
# Epoch 9/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3985 - accuracy: 0.8265
# Epoch 10/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8276
# Epoch 11/20
# 288/288 [==============================] - 1s 2ms/step - loss: 0.3927 - accuracy: 0.8283
# Epoch 12/20
# 288/288 [==============================] - 0s 2ms/step - loss: 0.3899 - accuracy: 0.8310
# Epoch 13/20
#  97/288 [=========>....................] - ETA: 0s - loss: 0.3950 - accuracy: 0.8256

# %%
print(mean, variance)
# Out:
# 0.8542499899864197 0.012338959969295191
