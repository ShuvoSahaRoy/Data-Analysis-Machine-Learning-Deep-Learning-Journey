# %% [markdown]
# # Statistics - Exploratory Data Analysis
#
# - Histogram plots
# - Scatter plots
# - Percentiles
# - Boxplots
# - Violin
# - Heatmaps
# - Barplots
# - Factor plots
# - Density plots
# - Joint Distribution plots

# %%
import pandas as pd
import numpy as np

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/winequalityN.csv"
df = pd.read_csv(file_name)
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df.shape
# Out:
# (6497, 13)

# %% [markdown]
# ### Simple Descriptive Analysis

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df[df['fixed acidity'].isnull()].shape
# Out:
# (10, 13)

# %%
df["alcohol"].mean()
# Out:
# 10.491800831149455

# %% [markdown]
# # Let's start plotting using a Histogram

# %%
df.hist(column='alcohol', bins=15)
# Out:
# array([[<AxesSubplot: title={'center': 'alcohol'}>]], dtype=object)

# %%
df[(df['alcohol']>9.5) & (df['alcohol']<10)]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 3     white            7.2              0.23         0.32            8.50
# 4     white            7.2              0.23         0.32            8.50
# 6     white            6.2              0.32         0.16            7.00
# 11    white            8.6              0.23         0.40            4.20
# 14    white            8.3              0.42         0.62           19.25
# ...     ...            ...               ...          ...             ...
# 6454    red            6.6              0.88         0.04            2.20
# 6457    red            7.8              0.60         0.26            2.00
# 6458    red            7.8              0.60         0.26            2.00
# 6459    red            7.8              0.60         0.26            2.00
# 6481    red            6.2              0.46         0.29            2.10
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# 6         0.045                 30.0                 136.0  0.99490  3.18
# 11        0.035                 17.0                 109.0  0.99470  3.14
# 14        0.040                 41.0                 172.0  1.00020  2.98
# ...         ...                  ...                   ...      ...   ...
# 6454      0.066                 12.0                  20.0  0.99636  3.53
# 6457      0.080                 31.0                 131.0  0.99622  3.21
# 6458      0.080                 31.0                 131.0  0.99622  3.21
# 6459      0.080                 31.0                 131.0  0.99622  3.21
# 6481      0.074                 32.0                  98.0  0.99578  3.33
#
#       sulphates  alcohol  quality
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# 6          0.47      9.6        6
# 11         0.53      9.7        5
# 14         0.67      9.7        5
# ...         ...      ...      ...
# 6454       0.56      9.9        5
# 6457       0.52      9.9        5
# 6458       0.52      9.9        5
# 6459       0.52      9.9        5
# 6481       0.62      9.8        5
#
# [731 rows x 13 columns]

# %%
# Let's get a bit more advanced and learn to customize your plots

df.hist(column='alcohol', bins=10, grid=False, figsize=(10,6), color='green')
# Out:
# array([[<AxesSubplot: title={'center': 'alcohol'}>]], dtype=object)

# %% [markdown]
# # These look nice, but using the library Seaborn, we can quickly produce even nicer plots

# %%
import seaborn as sns

sns.histplot(df['alcohol'], bins=25, kde=False)
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(df.alcohol, bins=10, kde=True, color="red")
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='Count'>

# %%
df["alcohol"].value_counts().head()
# Out:
# 9.5     367
# 9.4     332
# 9.2     271
# 10.0    229
# 10.5    227
# Name: alcohol, dtype: int64

# %% [markdown]
# # Styling and Axis Labels
# https://seaborn.pydata.org/tutorial/aesthetics.html?highlight=style

# %%
# Let's start with labeling our axis

import matplotlib.pyplot as plt

sns.histplot(df.alcohol)
plt.xlabel('Alcohol Percentage')
plt.ylabel('Count')
plt.title("Alcohol Content")
plt.show()

# %%
#Use sns.set_style() to control styling

sns.set_style("dark")
sns.distplot(df.alcohol, bins=15)
# Out:
# C:\Users\sshuv\AppData\Local\Temp\ipykernel_13036\1921091708.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.alcohol, bins=15)
# <AxesSubplot: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Scatter Plots

# %%
sns.lmplot(x='alcohol', y='fixed acidity', data=df)

# %%
sns.lmplot(x='alcohol', y='density', data=df, fit_reg=False)

# %%
# Scatterplot arguments
sns.lmplot(x='alcohol', y='chlorides', data=df,
           fit_reg=False, # Remove the regression line
           hue='quality')   # Color by quality

# %% [markdown]
# # Understanding Percentiles

# %%
# The quantile function 

print(df["alcohol"].quantile(0.1))
print(df["alcohol"].quantile(0.5))
print(df["alcohol"].quantile(0.9))
print(df["alcohol"].quantile(0.99))
# Out:
# 9.1
# 10.3
# 12.3
# 13.4

# %%
# What's the max alcohol value though?
df["alcohol"].max()
# Out:
# 14.9

# %%
# Quantile ranges

df["alcohol"].quantile(([0.05, 0.95]))
# Out:
# 0.05     9.0
# 0.95    12.7
# Name: alcohol, dtype: float64

# %% [markdown]
# # Boxplots & Finding Outliers
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# ![alt text](https://pro.arcgis.com/en/pro-app/help/analysis/geoprocessing/charts/GUID-0E2C3730-C535-40CD-8152-80D794A996A7-web.png)
#
# “maximum”: Q3 + 1.5*IQR
#
# “minimum”: Q1 -1.5*IQR

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['alcohol'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64
# <AxesSubplot: >

# %%
sns.boxplot(data=df, palette="Set3")
# Out:
# <AxesSubplot: >

# %%
from matplotlib import pyplot as plt

# Enlarge the plot
plt.figure(figsize=(12,8))

summary = df.drop(['free sulfur dioxide', 'total sulfur dioxide', 'quality',
                   'residual sugar', 'fixed acidity', 'alcohol'], axis=1)
sns.boxplot(data=summary, palette="Set3")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Violin Plots

# %%
sns.violinplot(data=df['alcohol'])
# Out:
# <AxesSubplot: >

# %%
# Bar Plot

# Enlarge the plot
plt.figure(figsize=(12,8))

sns.countplot(x='quality', data=df, hue='type')
# Out:
# <AxesSubplot: xlabel='quality', ylabel='count'>

# %%
# Titanic Example

sns.set(style="whitegrid")

# Load the example Titanic dataset
titanic = sns.load_dataset("titanic")

# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="class", y="survived", hue="sex", data=titanic,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("survival probability")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# Density Plot: Kernel Distribution Estimation Plot 
sns.kdeplot(data=titanic, x="age")
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
# Density Plot: band width adjustment
sns.kdeplot(data=titanic, x="age",bw_adjust=0.5)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
# Density Plot: band width adjustment
sns.kdeplot(data=titanic, x="age",bw_adjust=0.5, hue = "sex")
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=titanic, x="age",bw_adjust=0.5, hue = "sex", multiple = "stack")
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
# Joint Distribution Plot
sns.jointplot(x='alcohol', y='density', data=df)

# %% [markdown]
# # Factor Plots and Bee Swarm Plots
#
# Factor plots allow us to create separate plots by categorical classes.

# %%
df[['free sulfur dioxide','alcohol']]
# Out:
#       free sulfur dioxide  alcohol
# 0                    45.0      8.8
# 1                    14.0      9.5
# 2                    30.0     10.1
# 3                    47.0      9.9
# 4                    47.0      9.9
# ...                   ...      ...
# 6492                 32.0     10.5
# 6493                 39.0     11.2
# 6494                 29.0     11.0
# 6495                 32.0     10.2
# 6496                 18.0     11.0
#
# [6497 rows x 2 columns]

# %%
sns.swarmplot(data=df, y='alcohol',orient="h", size=3)
# Out:
# E:\codes\python\Journey Data Analysis & Machine Learning\ML ENVIRONMENT\lib\site-packages\seaborn\_oldcore.py:1592: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# <AxesSubplot: ylabel='alcohol'>
# E:\codes\python\Journey Data Analysis & Machine Learning\ML ENVIRONMENT\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 39.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# # Factor Plot
# g = sns.factor|plot(x='free sulfur dioxide', 
#                    y='alcohol', 
#                    data=df, 
# #                    A recent update in Matplotlib broke how the hue argument works in Seaborn with some plots see: https://github.com/mwaskom/seaborn/issues/1697
#                    hue='quality',  # Color by stage
#                    col='quality',  # Separate by stage
#                    kind='point'), # Swarmplot
# #                   orient="h", size=1
# # )
 
# # Rotate x-axis labels
# g.set_xticklabels(rotation=-45)

# %% [markdown]
# # Creating Empirical cumulative distribution function (ECDF)

# %%
import numpy as np

x = np.sort(df['alcohol'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.05)
_ = plt.xlabel('Percent of Alcohol in Wine') 
_ = plt.ylabel('ECDF') 
plt.grid(True)
plt.show()

# %%
print(df["alcohol"].quantile(([0.2, 0.8])))
# Out:
# 0.2     9.4
# 0.8    11.5
# Name: alcohol, dtype: float64
